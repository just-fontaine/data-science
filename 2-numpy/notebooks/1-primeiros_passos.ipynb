# %%
# Importando as biblitoecas
import numpy as np
import pandas as pd

# %%
# Fazendo uma soma de arrays de diferentes dimensões

a = np.array(
    [
        [1, 2],
        [3, 4]
    ]
)

b = np.array(
    [10, 20]
)

resultado = a + b

print(resultado)
# Out:
# [[11 22]
#  [13 24]]

# %% [markdown]
# #### A Soma funciona da seguinte forma:
#
# ![image.png](attachment:image.png)
#
# #### Ou seja, a array unidimensional é duplicada para que seja possível realizar a soma.

# %%
# Carregando o arquivo com o pandas
apples = pd.read_csv(
    r'C:\Estudos\alura\data-science\2-numpy\numpy-dados\apples_ts.csv', sep=','
)
apples.rename(columns={'Unnamed: 0': 'City'}, inplace=True)

apples
# Out:
#            City  1.2013  2.2013  3.2013  4.2013  5.2013  6.2013  7.2013  \
# 0        Moscow   79.72   81.08   79.68   79.80   80.63   80.80   80.28
# 1   Kaliningrad   42.67   44.37   44.73   46.75     NaN   51.59   57.80
# 2    Petersburg   62.55   62.73   63.43   63.83   66.06   69.22   72.07
# 3     Krasnodar   48.26   51.01   50.91   53.94   61.27   65.44   56.51
# 4  Ekaterinburg   71.25   71.35   70.90   71.92   72.91   74.39   73.10
#
#    8.2013  9.2013  ...  6.2019  7.2019  8.2019  9.2019  10.2019  11.2019  \
# 0   78.99   76.77  ...  116.91  125.29  123.94  113.03   102.19    97.83
# 1   62.14   56.76  ...   79.20   80.85   85.33   75.02    77.95    78.98
# 2   69.31   65.18  ...  115.35  123.03  123.08  109.71    97.22    95.75
# 3   53.00   43.87  ...  102.01  116.12   92.06   82.70    66.62    68.11
# 4   70.24   69.12  ...  121.68  125.32  123.41  108.48    98.73    96.25
#
#    12.2019  1.2020  2.2020  3.2020
# 0   101.07  103.44  108.23  110.28
# ...

# %%
# Calculando quantidade de colunas

7 * 12 + 3
# Out:
# 87

# %%
# Indo do índice 1, até o 87 (+ 1 pra tornar inclusivo), de 1 em 1

colunas = np.arange(
    1, 87 + 1, 1
)

# %%
# Carregando o arquivo com o numpy

dados_arquivo = np.loadtxt(
    r'C:\Estudos\alura\data-science\2-numpy\numpy-dados\apples_ts.csv',
    delimiter=',',
    usecols=colunas
)

print(dados_arquivo[:2])
# Out:
# [[  1.2013   2.2013   3.2013   4.2013   5.2013   6.2013   7.2013   8.2013
#     9.2013  10.2013  11.2013  12.2013   1.2014   2.2014   3.2014   4.2014
#     5.2014   6.2014   7.2014   8.2014   9.2014  10.2014  11.2014  12.2014
#     1.2015   2.2015   3.2015   4.2015   5.2015   6.2015   7.2015   8.2015
#     9.2015  10.2015  11.2015  12.2015   1.2016   2.2016   3.2016   4.2016
#     5.2016   6.2016   7.2016   8.2016   9.2016  10.2016  11.2016  12.2016
#     1.2017   2.2017   3.2017   4.2017   5.2017   6.2017   7.2017   8.2017
#     9.2017  10.2017  11.2017  12.2017   1.2018   2.2018   3.2018   4.2018
#     5.2018   6.2018   7.2018   8.2018   9.2018  10.2018  11.2018  12.2018
#     1.2019   2.2019   3.2019   4.2019   5.2019   6.2019   7.2019   8.2019
#     9.2019  10.2019  11.2019  12.2019   1.202    2.202    3.202 ]
#  [ 79.72    81.08    79.68    79.8     80.63    80.8     80.28    78.99
#    76.77    76.09    76.36    77.16    77.5     79.03    80.28    80.05
# ...

# %% [markdown]
# ### Carregando os dados direto do GitHub

# %% [markdown]
# #### Clicar na opção Raw
#
# ![image.png](attachment:image.png)
#
# #### Depois copiar a URL
#
# ![image-2.png](attachment:image-2.png)

# %%
url = 'https://raw.githubusercontent.com/alura-cursos/numpy/dados/apples_ts.csv'

# %%
# Carrega os dados através da url
dados_url = np.loadtxt(
    url,
    usecols=colunas,
    delimiter=','
)

print(dados_url[:2])
# Out:
# [[  1.2013   2.2013   3.2013   4.2013   5.2013   6.2013   7.2013   8.2013
#     9.2013  10.2013  11.2013  12.2013   1.2014   2.2014   3.2014   4.2014
#     5.2014   6.2014   7.2014   8.2014   9.2014  10.2014  11.2014  12.2014
#     1.2015   2.2015   3.2015   4.2015   5.2015   6.2015   7.2015   8.2015
#     9.2015  10.2015  11.2015  12.2015   1.2016   2.2016   3.2016   4.2016
#     5.2016   6.2016   7.2016   8.2016   9.2016  10.2016  11.2016  12.2016
#     1.2017   2.2017   3.2017   4.2017   5.2017   6.2017   7.2017   8.2017
#     9.2017  10.2017  11.2017  12.2017   1.2018   2.2018   3.2018   4.2018
#     5.2018   6.2018   7.2018   8.2018   9.2018  10.2018  11.2018  12.2018
#     1.2019   2.2019   3.2019   4.2019   5.2019   6.2019   7.2019   8.2019
#     9.2019  10.2019  11.2019  12.2019   1.202    2.202    3.202 ]
#  [ 79.72    81.08    79.68    79.8     80.63    80.8     80.28    78.99
#    76.77    76.09    76.36    77.16    77.5     79.03    80.28    80.05
# ...

# %%
# Mostra quantas dimensões possui

dados_url.ndim
# Out:
# 2

# %%
# Número de linhas e colunas respectivamente

dados_url.shape
# Out:
# (6, 87)

# %%
# Transpõe os dados

dados_transpostos = dados_url.T
dados_transpostos.shape
# Out:
# (87, 6)

# %%
dados_transpostos[:, 0]
# Out:
# array([ 1.2013,  2.2013,  3.2013,  4.2013,  5.2013,  6.2013,  7.2013,
#         8.2013,  9.2013, 10.2013, 11.2013, 12.2013,  1.2014,  2.2014,
#         3.2014,  4.2014,  5.2014,  6.2014,  7.2014,  8.2014,  9.2014,
#        10.2014, 11.2014, 12.2014,  1.2015,  2.2015,  3.2015,  4.2015,
#         5.2015,  6.2015,  7.2015,  8.2015,  9.2015, 10.2015, 11.2015,
#        12.2015,  1.2016,  2.2016,  3.2016,  4.2016,  5.2016,  6.2016,
#         7.2016,  8.2016,  9.2016, 10.2016, 11.2016, 12.2016,  1.2017,
#         2.2017,  3.2017,  4.2017,  5.2017,  6.2017,  7.2017,  8.2017,
#         9.2017, 10.2017, 11.2017, 12.2017,  1.2018,  2.2018,  3.2018,
#         4.2018,  5.2018,  6.2018,  7.2018,  8.2018,  9.2018, 10.2018,
#        11.2018, 12.2018,  1.2019,  2.2019,  3.2019,  4.2019,  5.2019,
#         6.2019,  7.2019,  8.2019,  9.2019, 10.2019, 11.2019, 12.2019,
#         1.202 ,  2.202 ,  3.202 ])

# %%
# Todas as linhas da primeira coluna, onde está localizada as datas

datas = dados_transpostos[:, 0]

# %%
# Todas as linhas, da coluna 1 até o final

precos = dados_transpostos[:, 1:]

# %%
import matplotlib.pyplot as plt

# %%
datas = np.arange(1, 87 + 1, 1)

# %%
# Pega todas as datas, e no preço pega todas as linhas da primeira cidade

#        eixo x, eixo y
plt.plot(datas, precos[:, 0])

# %%
apples
# Out:
#            City  1.2013  2.2013  3.2013  4.2013  5.2013  6.2013  7.2013  \
# 0        Moscow   79.72   81.08   79.68   79.80   80.63   80.80   80.28
# 1   Kaliningrad   42.67   44.37   44.73   46.75     NaN   51.59   57.80
# 2    Petersburg   62.55   62.73   63.43   63.83   66.06   69.22   72.07
# 3     Krasnodar   48.26   51.01   50.91   53.94   61.27   65.44   56.51
# 4  Ekaterinburg   71.25   71.35   70.90   71.92   72.91   74.39   73.10
#
#    8.2013  9.2013  ...  6.2019  7.2019  8.2019  9.2019  10.2019  11.2019  \
# 0   78.99   76.77  ...  116.91  125.29  123.94  113.03   102.19    97.83
# 1   62.14   56.76  ...   79.20   80.85   85.33   75.02    77.95    78.98
# 2   69.31   65.18  ...  115.35  123.03  123.08  109.71    97.22    95.75
# 3   53.00   43.87  ...  102.01  116.12   92.06   82.70    66.62    68.11
# 4   70.24   69.12  ...  121.68  125.32  123.41  108.48    98.73    96.25
#
#    12.2019  1.2020  2.2020  3.2020
# 0   101.07  103.44  108.23  110.28
# ...

# %%
# Pega todas os preços de cada cidade

moscow = precos[:, 0]
kaliningrad = precos[:, 1]
petersburg = precos[:, 2]
krasnodar = precos[:, 3]
ekaterinburg = precos[:, 4]

# %%
# Mostra as datas no eixo X e os preços de todas as cidades no eixo Y

plt.plot(datas, precos[:])

# %%
# Separa a cidade de moscou por anos

moscow_ano1 = moscow[0:12] 
moscow_ano2 = moscow[12:24]
moscow_ano3 = moscow[24:36]
moscow_ano4 = moscow[36:48]

# %%
# Mostra os 4 anos

plt.plot(np.arange(1, 12 + 1), moscow_ano1)
plt.plot(np.arange(1, 12 + 1), moscow_ano2)
plt.plot(np.arange(1, 12 + 1), moscow_ano3)
plt.plot(np.arange(1, 12 + 1), moscow_ano4)

# Adiciona uma legenda

plt.legend(
    ['Ano 1', 'Ano 2', 'Ano 3', 'Ano 4']
)

# %%
# Verifica se os anos 3 e 4 são iguais

np.array_equal(moscow_ano3, moscow_ano4)
# Out:
# False

# %%
# Verifica se os anos 1 e 2 são 0.5 parecidos

np.allclose(moscow_ano1, moscow_ano2, 0.5)
# Out:
# True

# %%
# Mostra a cidade de kaliningrad

plt.plot(datas, kaliningrad)

# %%
# Verifica quantos NaN existem

# %time np.sum(np.isnan(kaliningrad))
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# np.int64(1)

# %%
# Pega os índices de todos os NaN

indice_nan = np.where(np.isnan(kaliningrad))

indice_nan
# Out:
# (array([4]),)

# %%
# Faz a média do anterior e posterior ao NaN

(kaliningrad[4 - 1] + kaliningrad[4 + 1]) / 2
# Out:
# np.float64(49.17)

# %%
# Calcula a média utilizando uma função do numpy

kaliningrad[4] = np.mean(
    [
        kaliningrad[3],
        kaliningrad[5]
    ]
)

# %%
# Fazendo o plot com o NaN corrigido

plt.plot(datas, kaliningrad)

# %%
# Realizando as médias de duas cidades e mostrando na tela

print(
    f'Média de Moscow: {np.mean(moscow)}',
    f'Média de Kaliningrad: {np.mean(kaliningrad)}'
)
# Out:
# Média de Moscow: 98.79781609195402 Média de Kaliningrad: 74.5506896551724

# %%
plt.plot(datas, moscow)

# %% [markdown]
# <h3>
#     <center>
#         Equação da reta: Y = AX + B
#     </center>
# </h3>
#
# <p>
#     Neste caso:
#
#     Y = Preço
#     X = Meses
#     A = Coeficiente Angular
#     B = Coeficiente Linear
# </p>

# %%
x = datas

y = 2*x + 80

# %%
plt.plot(datas, moscow)
plt.plot(x, y)

# %%
np.sqrt(np.sum(np.power(moscow-y, 2)))
# Out:
# np.float64(749.2329171225728)

# %%
y = 0.52*x + 80

# %%
plt.plot(datas, moscow)
plt.plot(x, y)

# %%
np.sqrt(np.sum(np.power(moscow-y, 2)))
# Out:
# np.float64(110.48504740461489)

# %%
np.linalg.norm(moscow - y)
# Out:
# np.float64(110.48504740461489)

# %% [markdown]
# #### Criando cópia da forma correta

# %%
lista_1 = [1, 2, 3, 4, 5]

array_1 = np.array(lista_1)

array_2 = np.copy(array_1)

array_2[0] = 6

print(array_1, array_2)
# Out:
# [1 2 3 4 5] [6 2 3 4 5]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
Y = moscow
X = datas
n = np.size(moscow)

# %%
(X**2).shape
# Out:
# (87,)

# %%
a = (n*np.sum(X*Y) - np.sum(X)*np.sum(Y)) / (n*np.sum(X**2) - np.sum(X)**2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
b = np.mean(Y) - a*np.mean(X)

# %%
y = a*X+b

# %%
np.linalg.norm(moscow - y)
# Out:
# np.float64(101.7969539992751)

# %%
plt.plot(datas, moscow)
plt.plot(x, y)
plt.plot(100, 100*a+b, '*r')

# %%
coef_angulares = np.random.uniform(low=0.10, high=0.90, size=100)

# %%
norma = np.array([])

# %%
for i in range(100):
    norma = np.append(norma, np.linalg.norm(moscow - (coef_angulares[i]*X+b)))

# %%
norma
# Out:
# array([171.09464403, 160.1811662 , 125.87600824, 103.06317492,
#        213.00094989, 177.2821007 , 145.6173543 , 142.46198405,
#        218.46236692, 126.01788495, 105.35471064, 125.93250573,
#        156.35515999, 156.72295919, 111.52270067, 152.23704498,
#        127.31949514, 222.50401948, 115.73365338, 145.59842217,
#        235.44108489, 137.77003305, 152.69454965, 113.32228892,
#        189.00251169, 159.62024636, 109.40697574, 109.47704707,
#        154.76792456, 173.99528728, 111.41028015, 222.2573396 ,
#        187.92973175, 184.64369081, 227.82857275, 133.93259099,
#        145.91679299, 102.2763963 , 101.82954162, 108.34229476,
#        208.90731249, 151.15501075, 110.53081211, 166.65695357,
#        124.04380529, 105.94862732, 138.09336542, 145.53179323,
#        166.36906186, 213.03617394, 150.90473706, 102.92033676,
#        108.05795634, 118.13060343, 108.85793769, 145.30455869,
#        142.19184733, 237.86967126, 175.98403598, 197.93080232,
# ...

# %%
norma[38]
# Out:
# np.float64(101.82954161722509)

# %%
np.random.seed(16)
np.random.uniform(low=0.10, high=0.90, size=100)
# Out:
# array([0.27863286, 0.51853067, 0.54056117, 0.13648156, 0.38858307,
#        0.27846475, 0.65098093, 0.23098514, 0.15625989, 0.85280869,
#        0.5509451 , 0.16239387, 0.67811241, 0.22676174, 0.30022505,
#        0.3347898 , 0.65728857, 0.47141127, 0.27204971, 0.45746101,
#        0.196703  , 0.83414961, 0.55315706, 0.47761545, 0.35165314,
#        0.13457258, 0.70195593, 0.53461524, 0.71375234, 0.73235901,
#        0.1577771 , 0.62777267, 0.14263947, 0.64801956, 0.45468077,
#        0.47439692, 0.62884747, 0.65197331, 0.31066359, 0.10918315,
#        0.71703556, 0.75291386, 0.21171328, 0.5624054 , 0.37253942,
#        0.28577239, 0.258915  , 0.31719262, 0.88148221, 0.27234318,
#        0.38512593, 0.11471996, 0.59343222, 0.28432431, 0.69388139,
#        0.56740017, 0.43608284, 0.66740227, 0.87763642, 0.74803129,
#        0.44452414, 0.86618288, 0.13820648, 0.68622544, 0.64053316,
#        0.52160413, 0.55358996, 0.6783562 , 0.64608268, 0.73625014,
# ...

# %%
np.random.seed(84)
coef_angulares = np.random.uniform(low=0.10, high=0.90, size=100)

norma2 = np.array([])
for i in range(100):
    norma2 = np.append(norma2, np.linalg.norm(moscow - (coef_angulares[i]*X+b)))

# %%
norma2
# Out:
# array([173.90151233, 103.45241986, 121.75367289, 128.97173036,
#        238.69504078, 149.16590195, 137.73123242, 118.54419212,
#        101.79720981, 149.04689147, 112.80225228, 105.8049351 ,
#        230.82444742, 111.69709582, 134.56525603, 110.93209631,
#        204.12484401, 196.82117307, 221.88687726, 156.13691054,
#        125.51272174, 136.46474504, 165.39506278, 240.68784732,
#        104.52254473, 188.75637903, 131.2292927 , 128.94885341,
#        234.70773582, 147.01799832, 113.7418054 , 116.94496221,
#        109.58257043, 107.09546548, 145.00728041, 182.83818792,
#        140.95017242, 106.12371866, 107.0915778 , 132.45242448,
#        144.8736358 , 143.54772697, 240.23793834, 113.74604121,
#        116.01191029, 152.02977343, 174.72333708, 141.8068161 ,
#        101.93467119, 103.01538109, 169.59787792, 128.13083711,
#        105.06648948, 101.83421597, 102.53716362, 113.63850533,
#        219.96993004, 117.37921502, 182.70217805, 146.69612581,
# ...

# %%
coef_angulares
# Out:
# array([0.13683279, 0.39619385, 0.29385461, 0.602784  , 0.89208805,
#        0.20447044, 0.23887133, 0.30665125, 0.43471917, 0.20481511,
#        0.3323601 , 0.49624488, 0.87360345, 0.33791189, 0.62144155,
#        0.52849032, 0.8096211 , 0.7916786 , 0.85242626, 0.18466651,
#        0.59057786, 0.24287265, 0.15934165, 0.89674619, 0.38501918,
#        0.77157959, 0.61045713, 0.2676991 , 0.88274155, 0.21072909,
#        0.54257849, 0.3133875 , 0.34935345, 0.36479868, 0.21666475,
#        0.75660734, 0.22889395, 0.4986747 , 0.36482516, 0.25587381,
#        0.21706205, 0.64938079, 0.89569528, 0.32780566, 0.55295355,
#        0.19624604, 0.13469036, 0.22628157, 0.44641143, 0.40177235,
#        0.1481411 , 0.59986997, 0.49023732, 0.4293729 , 0.46122788,
#        0.54208756, 0.84785549, 0.31153122, 0.11414346, 0.65873013,
#        0.74587422, 0.61387426, 0.52200325, 0.76589084, 0.38088747,
#        0.25165091, 0.11382762, 0.88457997, 0.74881915, 0.86863621,
# ...

# %%
dados = np.column_stack([norma2, coef_angulares])

# %%
dados.shape
# Out:
# (100, 2)

# %%
# np.savetxt('dados.csv', dados, delimiter=',')
